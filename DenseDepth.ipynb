# %% [markdown]
# # Parameters

# %%
batch_size     = 8
learning_rate  = 0.0001
epochs         = 5

# %% [markdown]
# # Define model

# %%
from model import DepthEstimate

model = DepthEstimate()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 4s 0us/step
# Base model loaded DenseNet169
#
# Model created.

# %%
# !gdown "1fdFu5NGXe4rTLYKD5wOqk9dl-eJOefXo&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fdFu5NGXe4rTLYKD5wOqk9dl-eJOefXo&confirm=t
# To: /content/nyu_data.zip
# 100% 4.40G/4.40G [01:13<00:00, 59.8MB/s]

# %%
# !unzip nyu_data.zip

# %% [markdown]
# # Data loader

# %%
from data import DataLoader

dl = DataLoader()
train_generator = dl.get_batched_dataset(batch_size)

print('Data loader ready.')
# Out:
# Data loader ready.

# %% [markdown]
# # Compile & Train

# %%
import tensorflow
from loss import depth_loss_function

optimizer = tensorflow.keras.optimizers.Adam(lr=learning_rate, amsgrad=True)

model.compile(loss=depth_loss_function, optimizer=optimizer)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Create checkpoint callback
import os
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tensorflow.keras.callbacks.ModelCheckpoint(checkpoint_path, save_weights_only=True, verbose=1)

# %%
# Start training
model.fit(train_generator, epochs=5, steps_per_epoch=dl.length//batch_size, callbacks=[cp_callback])
# Out:
# Epoch 1/5
# 6336/6336 [==============================] - ETA: 0s - loss: 0.1314
# Epoch 1: saving model to training_1/cp.ckpt
# 6336/6336 [==============================] - 6323s 992ms/step - loss: 0.1314
# Epoch 2/5
#  875/6336 [===>..........................] - ETA: 1:30:11 - loss: 0.0994
